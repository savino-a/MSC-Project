# %%
import logging
import numpy as np
from docplex.mp.model_reader import ModelReader
import math
import numpy as np
from docplex.mp.basic import Expr
from docplex.mp.model import Model
from docplex.mp.solution import SolveSolution
from docplex.util.status import JobSolveStatus
import cplex.callbacks as cpx_cb
#from docplex.mp.callbacks.cb_mixin import ModelCallbackMixin
from docplex.mp.model import Model
from docplex.mp.relax_linear import LinearRelaxer

# %% [markdown]
# # Sample 1D ising model with constraints

# %%
from docplex.mp.model import Model
opt_model = Model(name="MIP Model")

Nc= 100
## Nc is the number of segments in which we cut the track time
Ny= 2*Nc
## Ny is the number of spin sites

num_flip = 1
### we have to check the constraint

Dist=500
## Distance to travel
tol=10
## Tolerance of Distance
delta_v=1
## Rate of acceleration/deceleration set to 1
#vmax= 89
## Max speed of a TGV in France (in m/s)
vmax=30
alpha=0.05
## Regenerative braking efficiency

lambda1=0.1
lambda2=0.000001
lambda3=0.8
lambda4=0.1

J_i_j = 1
h_i = 0.05

y={}
for i in range(0, Ny):
    y[i]= opt_model.binary_var(name=f"y_{i}")


"Note that: original variables y[t] are binary variables {0,1}, "
"To convert it into the spin variables {+1, -1}, we have to transform s[t] = (-1+(2*y[t]))"
" when y[t]= 0 then s[t] = -1 and when y[t]= 1 then s[t] = 1 "

objective = opt_model.linear_expr()
## objective is the hamiltonian/energy value we want to minimize


## Energy:
for i in range(Nc):
    #objective += (delta_v**2) * y[i*2+1] - alpha*(delta_v**2)*y[i*2]
    objective += (delta_v**2) * y[i*2+1]
    

opt_model.minimize(objective)

## add constraint

opt_model.add_constraint(opt_model.sum( y[i*2] * y[i*2 +1] for i in range(Nc)) == 0 , "No simultaneous braking/acceleration constraint")
opt_model.add_constraint(opt_model.sum( (((Nc-i)*delta_v*y[i*2+1]-(Nc-i)*delta_v*y[i*2])) for i in range(Nc)) <= Dist+tol , "Max_Distance constraint")
opt_model.add_constraint(opt_model.sum( (((Nc-i)*delta_v*y[i*2+1]-(Nc-i)*delta_v*y[i*2])) for i in range(Nc)) >= Dist-tol , "Min_Distance constraint")  
opt_model.add_constraint(opt_model.sum( (y[i*2]-y[i*2 +1]) for i in range(Nc)) == 0 , "Net-Zero constraint")
opt_model.add_constraint(opt_model.sum( (delta_v*y[i*2 +1]) for i in range(Nc)) <= vmax , "Maximum Speed constraint")
#### Print the optimization model

opt_model.print_information() 

print(opt_model.prettyprint())
# Out:
# Model: MIP Model
#  - number of variables: 200
#    - binary=200, integer=0, continuous=0
#  - number of constraints: 5
#    - linear=4, quadratic=1
#  - parameters: defaults
#  - objective: minimize
#  - problem type is: MIQCP
# // This file has been generated by DOcplex
# // model name is: MIP Model
# // single vars section
# dvar bool y_0;
# dvar bool y_1;
# dvar bool y_2;
# dvar bool y_3;
# dvar bool y_4;
# dvar bool y_5;
# dvar bool y_6;
# dvar bool y_7;
# dvar bool y_8;
# dvar bool y_9;
# dvar bool y_10;
# dvar bool y_11;
# dvar bool y_12;
# dvar bool y_13;
# dvar bool y_14;
# dvar bool y_15;
# dvar bool y_16;
# dvar bool y_17;
# dvar bool y_18;
# dvar bool y_19;
# dvar bool y_20;
# dvar bool y_21;
# dvar bool y_22;
# dvar bool y_23;
# dvar bool y_24;
# dvar bool y_25;
# dvar bool y_26;
# dvar bool y_27;
# dvar bool y_28;
# dvar bool y_29;
# dvar bool y_30;
# dvar bool y_31;
# dvar bool y_32;
# dvar bool y_33;
# dvar bool y_34;
# dvar bool y_35;
# dvar bool y_36;
# dvar bool y_37;
# dvar bool y_38;
# dvar bool y_39;
# dvar bool y_40;
# dvar bool y_41;
# dvar bool y_42;
# dvar bool y_43;
# dvar bool y_44;
# dvar bool y_45;
# dvar bool y_46;
# dvar bool y_47;
# dvar bool y_48;
# dvar bool y_49;
# dvar bool y_50;
# dvar bool y_51;
# dvar bool y_52;
# dvar bool y_53;
# dvar bool y_54;
# dvar bool y_55;
# dvar bool y_56;
# dvar bool y_57;
# dvar bool y_58;
# dvar bool y_59;
# dvar bool y_60;
# dvar bool y_61;
# dvar bool y_62;
# dvar bool y_63;
# dvar bool y_64;
# dvar bool y_65;
# dvar bool y_66;
# dvar bool y_67;
# dvar bool y_68;
# dvar bool y_69;
# dvar bool y_70;
# dvar bool y_71;
# dvar bool y_72;
# dvar bool y_73;
# dvar bool y_74;
# dvar bool y_75;
# dvar bool y_76;
# dvar bool y_77;
# dvar bool y_78;
# dvar bool y_79;
# dvar bool y_80;
# dvar bool y_81;
# dvar bool y_82;
# dvar bool y_83;
# dvar bool y_84;
# dvar bool y_85;
# dvar bool y_86;
# dvar bool y_87;
# dvar bool y_88;
# dvar bool y_89;
# dvar bool y_90;
# dvar bool y_91;
# dvar bool y_92;
# dvar bool y_93;
# dvar bool y_94;
# dvar bool y_95;
# dvar bool y_96;
# dvar bool y_97;
# dvar bool y_98;
# dvar bool y_99;
# dvar bool y_100;
# dvar bool y_101;
# dvar bool y_102;
# dvar bool y_103;
# dvar bool y_104;
# dvar bool y_105;
# dvar bool y_106;
# dvar bool y_107;
# dvar bool y_108;
# dvar bool y_109;
# dvar bool y_110;
# dvar bool y_111;
# dvar bool y_112;
# dvar bool y_113;
# dvar bool y_114;
# dvar bool y_115;
# dvar bool y_116;
# dvar bool y_117;
# dvar bool y_118;
# dvar bool y_119;
# dvar bool y_120;
# dvar bool y_121;
# dvar bool y_122;
# dvar bool y_123;
# dvar bool y_124;
# dvar bool y_125;
# dvar bool y_126;
# dvar bool y_127;
# dvar bool y_128;
# dvar bool y_129;
# dvar bool y_130;
# dvar bool y_131;
# dvar bool y_132;
# dvar bool y_133;
# dvar bool y_134;
# dvar bool y_135;
# dvar bool y_136;
# dvar bool y_137;
# dvar bool y_138;
# dvar bool y_139;
# dvar bool y_140;
# dvar bool y_141;
# dvar bool y_142;
# dvar bool y_143;
# dvar bool y_144;
# dvar bool y_145;
# dvar bool y_146;
# dvar bool y_147;
# dvar bool y_148;
# dvar bool y_149;
# dvar bool y_150;
# dvar bool y_151;
# dvar bool y_152;
# dvar bool y_153;
# dvar bool y_154;
# dvar bool y_155;
# dvar bool y_156;
# dvar bool y_157;
# dvar bool y_158;
# dvar bool y_159;
# dvar bool y_160;
# dvar bool y_161;
# dvar bool y_162;
# dvar bool y_163;
# dvar bool y_164;
# dvar bool y_165;
# dvar bool y_166;
# dvar bool y_167;
# dvar bool y_168;
# dvar bool y_169;
# dvar bool y_170;
# dvar bool y_171;
# dvar bool y_172;
# dvar bool y_173;
# dvar bool y_174;
# dvar bool y_175;
# dvar bool y_176;
# dvar bool y_177;
# dvar bool y_178;
# dvar bool y_179;
# dvar bool y_180;
# dvar bool y_181;
# dvar bool y_182;
# dvar bool y_183;
# dvar bool y_184;
# dvar bool y_185;
# dvar bool y_186;
# dvar bool y_187;
# dvar bool y_188;
# dvar bool y_189;
# dvar bool y_190;
# dvar bool y_191;
# dvar bool y_192;
# dvar bool y_193;
# dvar bool y_194;
# dvar bool y_195;
# dvar bool y_196;
# dvar bool y_197;
# dvar bool y_198;
# dvar bool y_199;
#
# minimize
#  y_1 + y_3 + y_5 + y_7 + y_9 + y_11 + y_13 + y_15 + y_17 + y_19 + y_21 + y_23
#  + y_25 + y_27 + y_29 + y_31 + y_33 + y_35 + y_37 + y_39 + y_41 + y_43 + y_45
#  + y_47 + y_49 + y_51 + y_53 + y_55 + y_57 + y_59 + y_61 + y_63 + y_65 + y_67
#  + y_69 + y_71 + y_73 + y_75 + y_77 + y_79 + y_81 + y_83 + y_85 + y_87 + y_89
#  + y_91 + y_93 + y_95 + y_97 + y_99 + y_101 + y_103 + y_105 + y_107 + y_109
#  + y_111 + y_113 + y_115 + y_117 + y_119 + y_121 + y_123 + y_125 + y_127
#  + y_129 + y_131 + y_133 + y_135 + y_137 + y_139 + y_141 + y_143 + y_145
#  + y_147 + y_149 + y_151 + y_153 + y_155 + y_157 + y_159 + y_161 + y_163
#  + y_165 + y_167 + y_169 + y_171 + y_173 + y_175 + y_177 + y_179 + y_181
#  + y_183 + y_185 + y_187 + y_189 + y_191 + y_193 + y_195 + y_197 + y_199;
#
# subject to {
#  Max_Distance_constraint:
#   100 y_1 - 100 y_0 + 99 y_3 - 99 y_2 + 98 y_5 - 98 y_4 + 97 y_7 - 97 y_6
#   + 96 y_9 - 96 y_8 + 95 y_11 - 95 y_10 + 94 y_13 - 94 y_12 + 93 y_15
#   - 93 y_14 + 92 y_17 - 92 y_16 + 91 y_19 - 91 y_18 + 90 y_21 - 90 y_20
#   + 89 y_23 - 89 y_22 + 88 y_25 - 88 y_24 + 87 y_27 - 87 y_26 + 86 y_29
#   - 86 y_28 + 85 y_31 - 85 y_30 + 84 y_33 - 84 y_32 + 83 y_35 - 83 y_34
#   + 82 y_37 - 82 y_36 + 81 y_39 - 81 y_38 + 80 y_41 - 80 y_40 + 79 y_43
#   - 79 y_42 + 78 y_45 - 78 y_44 + 77 y_47 - 77 y_46 + 76 y_49 - 76 y_48
#   + 75 y_51 - 75 y_50 + 74 y_53 - 74 y_52 + 73 y_55 - 73 y_54 + 72 y_57
#   - 72 y_56 + 71 y_59 - 71 y_58 + 70 y_61 - 70 y_60 + 69 y_63 - 69 y_62
#   + 68 y_65 - 68 y_64 + 67 y_67 - 67 y_66 + 66 y_69 - 66 y_68 + 65 y_71
#   - 65 y_70 + 64 y_73 - 64 y_72 + 63 y_75 - 63 y_74 + 62 y_77 - 62 y_76
#   + 61 y_79 - 61 y_78 + 60 y_81 - 60 y_80 + 59 y_83 - 59 y_82 + 58 y_85
#   - 58 y_84 + 57 y_87 - 57 y_86 + 56 y_89 - 56 y_88 + 55 y_91 - 55 y_90
#   + 54 y_93 - 54 y_92 + 53 y_95 - 53 y_94 + 52 y_97 - 52 y_96 + 51 y_99
#   - 51 y_98 + 50 y_101 - 50 y_100 + 49 y_103 - 49 y_102 + 48 y_105 - 48 y_104
#   + 47 y_107 - 47 y_106 + 46 y_109 - 46 y_108 + 45 y_111 - 45 y_110 + 44 y_113
#   - 44 y_112 + 43 y_115 - 43 y_114 + 42 y_117 - 42 y_116 + 41 y_119 - 41 y_118
#   + 40 y_121 - 40 y_120 + 39 y_123 - 39 y_122 + 38 y_125 - 38 y_124 + 37 y_127
#   - 37 y_126 + 36 y_129 - 36 y_128 + 35 y_131 - 35 y_130 + 34 y_133 - 34 y_132
#   + 33 y_135 - 33 y_134 + 32 y_137 - 32 y_136 + 31 y_139 - 31 y_138 + 30 y_141
#   - 30 y_140 + 29 y_143 - 29 y_142 + 28 y_145 - 28 y_144 + 27 y_147 - 27 y_146
#   + 26 y_149 - 26 y_148 + 25 y_151 - 25 y_150 + 24 y_153 - 24 y_152 + 23 y_155
#   - 23 y_154 + 22 y_157 - 22 y_156 + 21 y_159 - 21 y_158 + 20 y_161 - 20 y_160
#   + 19 y_163 - 19 y_162 + 18 y_165 - 18 y_164 + 17 y_167 - 17 y_166 + 16 y_169
#   - 16 y_168 + 15 y_171 - 15 y_170 + 14 y_173 - 14 y_172 + 13 y_175 - 13 y_174
#   + 12 y_177 - 12 y_176 + 11 y_179 - 11 y_178 + 10 y_181 - 10 y_180 + 9 y_183
#   - 9 y_182 + 8 y_185 - 8 y_184 + 7 y_187 - 7 y_186 + 6 y_189 - 6 y_188
#   + 5 y_191 - 5 y_190 + 4 y_193 - 4 y_192 + 3 y_195 - 3 y_194 + 2 y_197
#   - 2 y_196 + y_199 - y_198 <= 510;
#  Min_Distance_constraint:
#   100 y_1 - 100 y_0 + 99 y_3 - 99 y_2 + 98 y_5 - 98 y_4 + 97 y_7 - 97 y_6
#   + 96 y_9 - 96 y_8 + 95 y_11 - 95 y_10 + 94 y_13 - 94 y_12 + 93 y_15
#   - 93 y_14 + 92 y_17 - 92 y_16 + 91 y_19 - 91 y_18 + 90 y_21 - 90 y_20
#   + 89 y_23 - 89 y_22 + 88 y_25 - 88 y_24 + 87 y_27 - 87 y_26 + 86 y_29
#   - 86 y_28 + 85 y_31 - 85 y_30 + 84 y_33 - 84 y_32 + 83 y_35 - 83 y_34
#   + 82 y_37 - 82 y_36 + 81 y_39 - 81 y_38 + 80 y_41 - 80 y_40 + 79 y_43
#   - 79 y_42 + 78 y_45 - 78 y_44 + 77 y_47 - 77 y_46 + 76 y_49 - 76 y_48
#   + 75 y_51 - 75 y_50 + 74 y_53 - 74 y_52 + 73 y_55 - 73 y_54 + 72 y_57
#   - 72 y_56 + 71 y_59 - 71 y_58 + 70 y_61 - 70 y_60 + 69 y_63 - 69 y_62
#   + 68 y_65 - 68 y_64 + 67 y_67 - 67 y_66 + 66 y_69 - 66 y_68 + 65 y_71
#   - 65 y_70 + 64 y_73 - 64 y_72 + 63 y_75 - 63 y_74 + 62 y_77 - 62 y_76
#   + 61 y_79 - 61 y_78 + 60 y_81 - 60 y_80 + 59 y_83 - 59 y_82 + 58 y_85
#   - 58 y_84 + 57 y_87 - 57 y_86 + 56 y_89 - 56 y_88 + 55 y_91 - 55 y_90
#   + 54 y_93 - 54 y_92 + 53 y_95 - 53 y_94 + 52 y_97 - 52 y_96 + 51 y_99
#   - 51 y_98 + 50 y_101 - 50 y_100 + 49 y_103 - 49 y_102 + 48 y_105 - 48 y_104
#   + 47 y_107 - 47 y_106 + 46 y_109 - 46 y_108 + 45 y_111 - 45 y_110 + 44 y_113
#   - 44 y_112 + 43 y_115 - 43 y_114 + 42 y_117 - 42 y_116 + 41 y_119 - 41 y_118
#   + 40 y_121 - 40 y_120 + 39 y_123 - 39 y_122 + 38 y_125 - 38 y_124 + 37 y_127
#   - 37 y_126 + 36 y_129 - 36 y_128 + 35 y_131 - 35 y_130 + 34 y_133 - 34 y_132
#   + 33 y_135 - 33 y_134 + 32 y_137 - 32 y_136 + 31 y_139 - 31 y_138 + 30 y_141
#   - 30 y_140 + 29 y_143 - 29 y_142 + 28 y_145 - 28 y_144 + 27 y_147 - 27 y_146
#   + 26 y_149 - 26 y_148 + 25 y_151 - 25 y_150 + 24 y_153 - 24 y_152 + 23 y_155
#   - 23 y_154 + 22 y_157 - 22 y_156 + 21 y_159 - 21 y_158 + 20 y_161 - 20 y_160
#   + 19 y_163 - 19 y_162 + 18 y_165 - 18 y_164 + 17 y_167 - 17 y_166 + 16 y_169
#   - 16 y_168 + 15 y_171 - 15 y_170 + 14 y_173 - 14 y_172 + 13 y_175 - 13 y_174
#   + 12 y_177 - 12 y_176 + 11 y_179 - 11 y_178 + 10 y_181 - 10 y_180 + 9 y_183
#   - 9 y_182 + 8 y_185 - 8 y_184 + 7 y_187 - 7 y_186 + 6 y_189 - 6 y_188
#   + 5 y_191 - 5 y_190 + 4 y_193 - 4 y_192 + 3 y_195 - 3 y_194 + 2 y_197
#   - 2 y_196 + y_199 - y_198 >= 490;
#  NetmZero_constraint:
#   y_0 - y_1 + y_2 - y_3 + y_4 - y_5 + y_6 - y_7 + y_8 - y_9 + y_10 - y_11
#   + y_12 - y_13 + y_14 - y_15 + y_16 - y_17 + y_18 - y_19 + y_20 - y_21 + y_22
#   - y_23 + y_24 - y_25 + y_26 - y_27 + y_28 - y_29 + y_30 - y_31 + y_32 - y_33
#   + y_34 - y_35 + y_36 - y_37 + y_38 - y_39 + y_40 - y_41 + y_42 - y_43 + y_44
#   - y_45 + y_46 - y_47 + y_48 - y_49 + y_50 - y_51 + y_52 - y_53 + y_54 - y_55
#   + y_56 - y_57 + y_58 - y_59 + y_60 - y_61 + y_62 - y_63 + y_64 - y_65 + y_66
#   - y_67 + y_68 - y_69 + y_70 - y_71 + y_72 - y_73 + y_74 - y_75 + y_76 - y_77
#   + y_78 - y_79 + y_80 - y_81 + y_82 - y_83 + y_84 - y_85 + y_86 - y_87 + y_88
#   - y_89 + y_90 - y_91 + y_92 - y_93 + y_94 - y_95 + y_96 - y_97 + y_98 - y_99
#   + y_100 - y_101 + y_102 - y_103 + y_104 - y_105 + y_106 - y_107 + y_108
#   - y_109 + y_110 - y_111 + y_112 - y_113 + y_114 - y_115 + y_116 - y_117
#   + y_118 - y_119 + y_120 - y_121 + y_122 - y_123 + y_124 - y_125 + y_126
#   - y_127 + y_128 - y_129 + y_130 - y_131 + y_132 - y_133 + y_134 - y_135
#   + y_136 - y_137 + y_138 - y_139 + y_140 - y_141 + y_142 - y_143 + y_144
#   - y_145 + y_146 - y_147 + y_148 - y_149 + y_150 - y_151 + y_152 - y_153
#   + y_154 - y_155 + y_156 - y_157 + y_158 - y_159 + y_160 - y_161 + y_162
#   - y_163 + y_164 - y_165 + y_166 - y_167 + y_168 - y_169 + y_170 - y_171
#   + y_172 - y_173 + y_174 - y_175 + y_176 - y_177 + y_178 - y_179 + y_180
#   - y_181 + y_182 - y_183 + y_184 - y_185 + y_186 - y_187 + y_188 - y_189
#   + y_190 - y_191 + y_192 - y_193 + y_194 - y_195 + y_196 - y_197 + y_198
#   - y_199 == 0;
#  Maximum_Speed_constraint:
#   y_1 + y_3 + y_5 + y_7 + y_9 + y_11 + y_13 + y_15 + y_17 + y_19 + y_21 + y_23
#   + y_25 + y_27 + y_29 + y_31 + y_33 + y_35 + y_37 + y_39 + y_41 + y_43 + y_45
#   + y_47 + y_49 + y_51 + y_53 + y_55 + y_57 + y_59 + y_61 + y_63 + y_65 + y_67
#   + y_69 + y_71 + y_73 + y_75 + y_77 + y_79 + y_81 + y_83 + y_85 + y_87 + y_89
#   + y_91 + y_93 + y_95 + y_97 + y_99 + y_101 + y_103 + y_105 + y_107 + y_109
#   + y_111 + y_113 + y_115 + y_117 + y_119 + y_121 + y_123 + y_125 + y_127
#   + y_129 + y_131 + y_133 + y_135 + y_137 + y_139 + y_141 + y_143 + y_145
#   + y_147 + y_149 + y_151 + y_153 + y_155 + y_157 + y_159 + y_161 + y_163
#   + y_165 + y_167 + y_169 + y_171 + y_173 + y_175 + y_177 + y_179 + y_181
#   + y_183 + y_185 + y_187 + y_189 + y_191 + y_193 + y_195 + y_197 + y_199 <=
#   30;
#  No_simultaneous_braking_acceleration_constraint:
#   [ y_0*y_1 + y_2*y_3 + y_4*y_5 + y_6*y_7 + y_8*y_9 + y_10*y_11 + y_12*y_13
#   + y_14*y_15 + y_16*y_17 + y_18*y_19 + y_20*y_21 + y_22*y_23 + y_24*y_25
#   + y_26*y_27 + y_28*y_29 + y_30*y_31 + y_32*y_33 + y_34*y_35 + y_36*y_37
#   + y_38*y_39 + y_40*y_41 + y_42*y_43 + y_44*y_45 + y_46*y_47 + y_48*y_49
#   + y_50*y_51 + y_52*y_53 + y_54*y_55 + y_56*y_57 + y_58*y_59 + y_60*y_61
#   + y_62*y_63 + y_64*y_65 + y_66*y_67 + y_68*y_69 + y_70*y_71 + y_72*y_73
#   + y_74*y_75 + y_76*y_77 + y_78*y_79 + y_80*y_81 + y_82*y_83 + y_84*y_85
#   + y_86*y_87 + y_88*y_89 + y_90*y_91 + y_92*y_93 + y_94*y_95 + y_96*y_97
#   + y_98*y_99 + y_100*y_101 + y_102*y_103 + y_104*y_105 + y_106*y_107
#   + y_108*y_109 + y_110*y_111 + y_112*y_113 + y_114*y_115 + y_116*y_117
#   + y_118*y_119 + y_120*y_121 + y_122*y_123 + y_124*y_125 + y_126*y_127
#   + y_128*y_129 + y_130*y_131 + y_132*y_133 + y_134*y_135 + y_136*y_137
#   + y_138*y_139 + y_140*y_141 + y_142*y_143 + y_144*y_145 + y_146*y_147
#   + y_148*y_149 + y_150*y_151 + y_152*y_153 + y_154*y_155 + y_156*y_157
#   + y_158*y_159 + y_160*y_161 + y_162*y_163 + y_164*y_165 + y_166*y_167
#   + y_168*y_169 + y_170*y_171 + y_172*y_173 + y_174*y_175 + y_176*y_177
#   + y_178*y_179 + y_180*y_181 + y_182*y_183 + y_184*y_185 + y_186*y_187
#   + y_188*y_189 + y_190*y_191 + y_192*y_193 + y_194*y_195 + y_196*y_197
#   + y_198*y_199 ] == 0;
#
# }
# None

# %%
result = opt_model.solve(log_output=True) #(log_output=self.solver_config.cplex_log)
y_value=[]
for l in range(0, Ny):
    y_value.append(result.get_value(f"y_{l}"))
    print(f"y_{l} =" , result.get_value(f"y_{l}")  )
    

print("Binary Variables" , y_value, "Objective value", result.objective_value )
# Out:
# Version identifier: 22.1.1.0 | 2022-11-26 | 9160aff4d
# CPXPARAM_Read_DataCheck                          1
# CPLEX Error  5002: 'No simultaneous braking/acceleration constraint' is not convex.
# Presolve time = 0.00 sec. (0.01 ticks)
#
# Root node processing (before b&c):
#   Real time             =    0.00 sec. (0.02 ticks)
# Parallel b&c, 20 threads:
#   Real time             =    0.00 sec. (0.00 ticks)
#   Sync time (average)   =    0.00 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =    0.00 sec. (0.02 ticks)
# Error: Model has non-convex quadratic constraint
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 4
#       2 y_value=[]
#       3 for l in range(0, Ny):
# ----> 4     y_value.append(result.get_value(f"y_{l}"))
#       5     print(f"y_{l} =" , result.get_value(f"y_{l}")  )
#       8 print("Binary Variables" , y_value, "Objective value", result.objective_value )
#
# AttributeError: 'NoneType' object has no attribute 'get_value'

# %% [markdown]
# ## Visualisation of results

# %%
import plotly.graph_objs as go
import plotly.offline as pyo
import numpy as np



def v(vini, a,b, delta_v):
    if a == 0 and b == 0:
        return vini
    elif a == 0 and b == 1:
        return vini + delta_v
    elif a == 1 and b == 0:
        return vini - delta_v
    else:
        return vini

def distance(speedi,speedi1):
    dstce=speedi + (speedi1-speedi)/2
    return dstce

def plot_speed(y, delta_v):
    N = len(y)
    speed = [0]

    for i in range(N // 2):
        speed.append(v(speed[i - 1], y[2 * i],y[2*i+1], delta_v))

    ditce=[0]
    for i in range(N//2-1):
        ditce.append(ditce[i]+distance(speed[i],speed[i+1]))
    plt.plot(ditce)
    N=N//2
    # Create the speed trace (first graph)
    trace_speed = go.Scatter(
        x=np.arange(0, N),
        y=speed,
        mode="lines",
        name="Speed vs Time",
        line=dict(color="royalblue", width=2),
        marker=dict(size=8, symbol="circle", line=dict(width=2, color="darkblue")),
    )

    # Create the layout for the speed graph
    layout_speed = go.Layout(
        title="Speed vs Time",
        titlefont=dict(size=24, family="Arial, sans-serif"),
        xaxis=dict(
            title="Time (s)",
            titlefont=dict(size=18, family="Arial, sans-serif"),
            showgrid=True,
            gridcolor="lightgray",
            zeroline=True,
            zerolinecolor="gray",
            tickfont=dict(size=14),
        ),
        yaxis=dict(
            title="Speed (m/s)",
            titlefont=dict(size=18, family="Arial, sans-serif"),
            showgrid=True,
            gridcolor="lightgray",
            zeroline=True,
            zerolinecolor="gray",
            tickfont=dict(size=14),
        ),
        plot_bgcolor="white",
        paper_bgcolor="rgba(255, 255, 255, 0.9)",
        showlegend=True,
    )

    # Create the figure for speed
    fig_speed = go.Figure(data=[trace_speed], layout=layout_speed)

    # Plot the speed graph
    pyo.plot(fig_speed, filename="speed_vs_time_with_contraints.html")

# %%
plot_speed(y_value,delta_v)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 plot_speed(y_value,delta_v)
#
# Cell In[76], line 31, in plot_speed(y, delta_v)
#      29 for i in range(N//2-1):
#      30     ditce.append(ditce[i]+distance(speed[i],speed[i+1]))
# ---> 31 plt.plot(ditce)
#      32 N=N//2
#      33 # Create the speed trace (first graph)
#
# NameError: name 'plt' is not defined
